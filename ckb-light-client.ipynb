# %%
rpc_url = 'https://testnet.ckbapp.dev'

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'set_scripts',
    'params': [
        [
            {
                'script': {
                    'code_hash': '0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8',
                    'hash_type': 'type',
                    'args': '0x5f58632a123e7e731db0b59ce50fe16579c7d941',
                },
                'script_type': 'lock',
                'block_number': '0x0',
            },
        ],
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_scripts',
    'params': [],
    'id': 1
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'send_transaction',
    'params': [
        {
            'cell_deps': [
                {
                    'dep_type': 'dep_group',
                    'out_point': {
                        'index': '0x0',
                        'tx_hash': '0xf8de3bb47d055cdf460d93a2a6e1b05f7432f9777c8c474abf4eec1d4aee5d37',
                    },
                },
            ],
            'header_deps': [],
            'inputs': [
                {
                    'previous_output': {
                        'index': '0x7',
                        'tx_hash': '0x8f8c79eb6671709633fe6a46de93c0fedc9c1b8a6527a18d3983879542635c9f',
                    },
                    'since': '0x0',
                },
            ],
            'outputs': [
                {
                    'capacity': '0x470de4df820000',
                    'lock': {
                        'args': '0xff5094c2c5f476fc38510018609a3fd921dd28ad',
                        'code_hash': '0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8',
                        'hash_type': 'type',
                    },
                    'type': None,
                },
                {
                    'capacity': '0xb61134e5a35e800',
                    'lock': {
                        'args': '0x64257f00b6b63e987609fa9be2d0c86d351020fb',
                        'code_hash': '0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8',
                        'hash_type': 'type',
                    },
                    'type': None,
                },
            ],
            'outputs_data': [
                '0x',
                '0x',
            ],
            'version': '0x0',
            'witnesses': [
                '0x5500000010000000550000005500000041000000af34b54bebf8c5971da6a880f2df5a186c3f8d0b5c9a1fe1a90c95b8a4fb89ef3bab1ccec13797dcb3fee80400f953227dd7741227e08032e3598e16ccdaa49c00',
            ],
        },
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_tip_header',
    'params': [],
    'id': 1
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_genesis_block',
    'params': [],
    'id': 1
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_header',
    'params': [
        '0xd11568c01b678900aab7f8678a48faadafaf044430b960f074ba2898005773a2',
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_transaction',
    'params': [
        '0x27a49f6b4588de2dae5ee593fbeef66a495985fb1cad645cd1844e874a8b6252',
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'fetch_header',
    'params': [
        '0x27a49f6b4588de2dae5ee593fbeef66a495985fb1cad645cd1844e874a8b6252',
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'fetch_transaction',
    'params': [
        '0x27a49f6b4588de2dae5ee593fbeef66a495985fb1cad645cd1844e874a8b6252',
    ],
    'id': 1,
}

response = requests.post('http://108.61.161.31:9000/', json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_cells',
    'params': [
        {
            "script": {
                "code_hash": "0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8",
                "hash_type": "type",
                "args": "0x5f58632a123e7e731db0b59ce50fe16579c7d941"
            },
            "script_type": "lock"
        },
        "asc",
        "0x64"
    ],
    'id': 2,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_transactions',
    'params': [
        {
            "script": {
                "code_hash": "0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8",
                "hash_type": "type",
                "args": "0x5f58632a123e7e731db0b59ce50fe16579c7d941"
            },
            "script_type": "lock",
            "group_by_transaction": True,
        },
        "desc",
        "0x64"
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)

# %%
import requests
import json

json_data = {
    'jsonrpc': '2.0',
    'method': 'get_cells_capacity',
    "params": [
        {
            "script": {
                "code_hash": "0x9bd7e06f3ecf4be0f2fcd2188b23f1b9fcc88e5d4b65a8637b17723bbda3cce8",
                "hash_type": "type",
                "args": "0x5f58632a123e7e731db0b59ce50fe16579c7d941"
            },
            "script_type": "lock"
        }
    ],
    'id': 1,
}

response = requests.post(rpc_url, json=json_data)
result = json.dumps(json.loads(response.content), indent=4)
print(result)
